# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-Abrahao/Alura-Machine-Learning/blob/main/Machine_Learning_lidando_com_dados_de_muitas_dimensoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
resultados_exames = pd.read_csv('/content/exames.csv')
resultados_exames.head()
# Out:
#          id diagnostico  exame_1  exame_2  exame_3  exame_4  exame_5  exame_6  \
# 0    842302           M    17.99    10.38   122.80   103.78   1001.0  0.11840
# 1    842517           M    20.57    17.77   132.90   103.78   1326.0  0.08474
# 2  84300903           M    19.69    21.25   130.00   103.78   1203.0  0.10960
# 3  84348301           M    11.42    20.38    77.58   103.78    386.1  0.14250
# 4  84358402           M    20.29    14.34   135.10   103.78   1297.0  0.10030
#
#    exame_7  exame_8  ...  exame_24  exame_25  exame_26  exame_27  exame_28  \
# 0  0.27760   0.3001  ...    184.60    2019.0    0.1622    0.6656    0.7119
# 1  0.07864   0.0869  ...    158.80    1956.0    0.1238    0.1866    0.2416
# 2  0.15990   0.1974  ...    152.50    1709.0    0.1444    0.4245    0.4504
# 3  0.28390   0.2414  ...     98.87     567.7    0.2098    0.8663    0.6869
# 4  0.13280   0.1980  ...    152.20    1575.0    0.1374    0.2050    0.4000
#
# ...

# %%
from sklearn.model_selection import train_test_split
from numpy import random

SEED = 123147
random.seed(SEED)

valores_exames = resultados_exames.drop(columns=['id', 'diagnostico'])
diagnostico = resultados_exames.diagnostico

treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames, diagnostico)

# %%
treino_x.head()
# Out:
#      exame_1  exame_2  exame_3  exame_4  exame_5  exame_6  exame_7  exame_8  \
# 520    9.295    13.90    59.96   103.78    257.8  0.13710  0.12250  0.03332
# 464   13.170    18.22    84.28   103.78    537.3  0.07466  0.05994  0.04859
# 70    18.940    21.31   123.60   103.78   1130.0  0.09009  0.10290  0.10800
# 72    17.200    24.52   114.20   103.78    929.4  0.10710  0.18300  0.16920
# 370   16.350    23.29   109.00   103.78    840.4  0.09742  0.14970  0.18110
#
#      exame_9  exame_10  ...  exame_24  exame_25  exame_26  exame_27  exame_28  \
# 520  0.02421    0.2197  ...     67.84     326.6    0.1850    0.2097   0.09996
# 464  0.02870    0.1454  ...     95.10     687.6    0.1282    0.1965   0.18760
# 70   0.07951    0.1582  ...    165.90    1866.0    0.1193    0.2336   0.26870
# 72   0.07944    0.1927  ...    151.60    1681.0    0.1585    0.7394   0.65660
# 370  0.08773    0.2175  ...    129.30    1165.0    0.1415    0.4665   0.70870
#
# ...

# %%
treino_y.head()
# Out:
# 520    B
# 464    B
# 70     M
# 72     M
# 370    M
# Name: diagnostico, dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier

classificador = RandomForestClassifier(n_estimators = 100)
classificador.fit(treino_x, treino_y)
print(classificador.score(teste_x, teste_y))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-b8b5c1f8be5d> in <module>()
#       2
#       3 classificador = RandomForestClassifier(n_estimators = 100)
# ----> 4 classificador.fit(treino_x, treino_y)
#       5 print(classificador.score(teste_x, teste_y))
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     326             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     327         X, y = self._validate_data(
# --> 328             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     329         )
#     330         if sample_weight is not None:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
# ...

# %%
resultados_exames.isnull().sum()
# Out:
# id               0
# diagnostico      0
# exame_1          0
# exame_2          0
# exame_3          0
# exame_4          0
# exame_5          0
# exame_6          0
# exame_7          0
# exame_8          0
# exame_9          0
# exame_10         0
# exame_11         0
# exame_12         0
# exame_13         0
# exame_14         0
# exame_15         0
# exame_16         0
# exame_17         0
# exame_18         0
# exame_19         0
# exame_20         0
# exame_21         0
# exame_22         0
# exame_23         0
# exame_24         0
# exame_25         0
# exame_26         0
# exame_27         0
# exame_28         0
# exame_29         0
# exame_30         0
# exame_31         0
# exame_32         0
# exame_33       419
# dtype: int64

# %% [markdown]
# quantos porcento de valores nulos temos na coluna exame_33

# %%
419/569
# Out:
# 0.7363796133567663

# %% [markdown]
# como a maioria é nula podemos excluir a coluna

# %%
SEED = 123147
random.seed(SEED)

valores_exames = resultados_exames.drop(columns=['id', 'diagnostico'])
diagnostico = resultados_exames.diagnostico
valores_exames_v1 = valores_exames.drop(columns = 'exame_33')

treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v1, diagnostico, test_size = 0.3)

classificador = RandomForestClassifier(n_estimators = 100)
classificador.fit(treino_x, treino_y)

print("Resultados da Classificação %.2f%%" %(classificador.score(teste_x, teste_y)*100))
# Out:
# Resultados da Classificação 96.49%

# %%
from sklearn.dummy import DummyClassifier

SEED = 123147
random.seed(SEED)

classificador_dummy = DummyClassifier(strategy = 'most_frequent')
classificador_dummy.fit(treino_x, treino_y)

print("Resultados da Classificação do Dummy %.2f%%" %(classificador_dummy.score(teste_x, teste_y)*100))
# Out:
# Resultados da Classificação do Dummy 64.91%

# %%
dados_plot = pd.concat([diagnostico, valores_exames_v1.iloc[:,0:10]], axis = 1)
dados_plot.head()
# Out:
#   diagnostico  exame_1  exame_2  exame_3  exame_4  exame_5  exame_6  exame_7  \
# 0           M    17.99    10.38   122.80   103.78   1001.0  0.11840  0.27760
# 1           M    20.57    17.77   132.90   103.78   1326.0  0.08474  0.07864
# 2           M    19.69    21.25   130.00   103.78   1203.0  0.10960  0.15990
# 3           M    11.42    20.38    77.58   103.78    386.1  0.14250  0.28390
# 4           M    20.29    14.34   135.10   103.78   1297.0  0.10030  0.13280
#
#    exame_8  exame_9  exame_10
# 0   0.3001  0.14710    0.2419
# 1   0.0869  0.07017    0.1812
# 2   0.1974  0.12790    0.2069
# 3   0.2414  0.10520    0.2597
# 4   0.1980  0.10430    0.1809

# %%
dados_plot = pd.melt(dados_plot, id_vars = 'diagnostico', var_name = 'exames', value_name = 'valores')
dados_plot.head()
# Out:
#   diagnostico   exames  valores
# 0           M  exame_1    17.99
# 1           M  exame_1    20.57
# 2           M  exame_1    19.69
# 3           M  exame_1    11.42
# 4           M  exame_1    20.29

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize = (10,10))

ax = sns.violinplot(x = 'exames', y = 'valores', hue = 'diagnostico', data = dados_plot)

# %%
from sklearn.preprocessing import StandardScaler

padronizador = StandardScaler()
padronizador.fit(valores_exames_v1)

valores_exames_v2 = padronizador.transform(valores_exames_v1)
valores_exames_v2 = pd.DataFrame(data = valores_exames_v2, columns =  valores_exames_v1.keys())

dados_plot = pd.concat([diagnostico, valores_exames_v2.iloc[:,0:10]], axis = 1)
dados_plot = pd.melt(dados_plot, id_vars = 'diagnostico', var_name = 'exames', value_name = 'valores')

plt.figure(figsize = (10,10))

ax = sns.violinplot(x = 'exames', y = 'valores', hue = 'diagnostico', data = dados_plot, split = True)

# %%
def grafico_violino(valores, inicio, fim):

  dados_plot = pd.concat([diagnostico, valores_exames_v2.iloc[:,inicio:fim]], axis = 1)
  dados_plot = pd.melt(dados_plot, id_vars = 'diagnostico', var_name = 'exames', value_name = 'valores')

  plt.figure(figsize = (12,12))

  ax = sns.violinplot(x = 'exames', y = 'valores', hue = 'diagnostico', data = dados_plot, split = True)

grafico_violino(valores_exames_v2,10,21)

# %%
grafico_violino(valores_exames_v2,21,32)

# %% [markdown]
# removendo as duas variaveis constantes

# %%
valores_exames_v3 = valores_exames_v2.drop(columns = ['exame_4','exame_29'])

def classificar(valores):

  SEED = 1234
  random.seed(SEED)

  treino_x, teste_x, treino_y, teste_y = train_test_split(valores, diagnostico, test_size = 0.3)

  classificador = RandomForestClassifier(n_estimators = 100)
  classificador.fit(treino_x, treino_y)

  print("Resultados da Classificação %.2f%%" %(classificador.score(teste_x, teste_y)*100))

classificar(valores_exames_v3)
# Out:
# Resultados da Classificação 92.98%

# %%
matriz_corr = valores_exames_v3.corr()

plt.figure(figsize = (17,15))
sns.heatmap(matriz_corr, annot = True, fmt = '.1f')

# %%
matriz_corr_v1 = matriz_corr[matriz_corr > 0.99]
matriz_corr_v1
# Out:
#            exame_1  exame_2   exame_3  exame_5  exame_6  exame_7  exame_8  \
# exame_1   1.000000      NaN  0.997855      NaN      NaN      NaN      NaN
# exame_2        NaN      1.0       NaN      NaN      NaN      NaN      NaN
# exame_3   0.997855      NaN  1.000000      NaN      NaN      NaN      NaN
# exame_5        NaN      NaN       NaN      1.0      NaN      NaN      NaN
# exame_6        NaN      NaN       NaN      NaN      1.0      NaN      NaN
# exame_7        NaN      NaN       NaN      NaN      NaN      1.0      NaN
# exame_8        NaN      NaN       NaN      NaN      NaN      NaN      1.0
# exame_9        NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_10       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_11       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_12       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# exame_13       NaN      NaN       NaN      NaN      NaN      NaN      NaN
# ...

# %%
matriz_corr_v2 = matriz_corr_v1.sum()

# %%
matriz_corr_v2
# Out:
# exame_1     1.997855
# exame_2     1.000000
# exame_3     1.997855
# exame_5     1.000000
# exame_6     1.000000
# exame_7     1.000000
# exame_8     1.000000
# exame_9     1.000000
# exame_10    1.000000
# exame_11    1.000000
# exame_12    1.000000
# exame_13    1.000000
# exame_14    1.000000
# exame_15    1.000000
# exame_16    1.000000
# exame_17    1.000000
# exame_18    1.000000
# exame_19    1.000000
# exame_20    1.000000
# exame_21    1.000000
# exame_22    1.993708
# exame_23    1.000000
# exame_24    1.993708
# exame_25    1.000000
# exame_26    1.000000
# exame_27    1.000000
# exame_28    1.000000
# exame_30    1.000000
# exame_31    1.000000
# exame_32    1.000000
# dtype: float64

# %%
variaveis_corr = matriz_corr_v2[matriz_corr_v2 > 1]
variaveis_corr
# Out:
# exame_1     1.997855
# exame_3     1.997855
# exame_22    1.993708
# exame_24    1.993708
# dtype: float64

# %% [markdown]
# excluindo as variaveis altamente correlacionadas

# %%
valores_exames_v4 = valores_exames_v3.drop(columns = variaveis_corr.keys())
valores_exames_v4
# Out:
#       exame_2   exame_5   exame_6   exame_7   exame_8   exame_9  exame_10  \
# 0   -2.073335  0.984375  1.568466  3.283515  2.652874  2.532475  2.217515
# 1   -0.353632  1.908708 -0.826962 -0.487072 -0.023846  0.548144  0.001392
# 2    0.456187  1.558884  0.942210  1.052926  1.363478  2.037231  0.939685
# 3    0.253732 -0.764464  3.283553  3.402909  1.915897  1.451707  2.867383
# 4   -1.151816  1.826229  0.280372  0.539340  1.371011  1.428493 -0.009560
# ..        ...       ...       ...       ...       ...       ...       ...
# 564  0.721473  2.343856  1.041842  0.219060  1.947285  2.320965 -0.312589
# 565  2.085134  1.723842  0.102458 -0.017833  0.693043  1.263669 -0.217664
# 566  2.045574  0.577953 -0.840484 -0.038680  0.046588  0.105777 -0.809117
# 567  2.336457  1.735218  1.525767  3.272144  3.296944  2.658866  2.137194
# 568  1.221792 -1.347789 -3.112085 -1.150752 -1.114873 -1.261820 -0.820070
#
#      exame_11  exame_12  exame_13  ...  exame_20  exame_21  exame_23  \
# ...

# %%
classificar(valores_exames_v4)
# Out:
# Resultados da Classificação 91.81%

# %%
valores_exames_v5 = valores_exames_v3.drop(columns = ['exame_3', 'exame_24'])
valores_exames_v5
# Out:
#       exame_1   exame_2   exame_5   exame_6   exame_7   exame_8   exame_9  \
# 0    1.097064 -2.073335  0.984375  1.568466  3.283515  2.652874  2.532475
# 1    1.829821 -0.353632  1.908708 -0.826962 -0.487072 -0.023846  0.548144
# 2    1.579888  0.456187  1.558884  0.942210  1.052926  1.363478  2.037231
# 3   -0.768909  0.253732 -0.764464  3.283553  3.402909  1.915897  1.451707
# 4    1.750297 -1.151816  1.826229  0.280372  0.539340  1.371011  1.428493
# ..        ...       ...       ...       ...       ...       ...       ...
# 564  2.110995  0.721473  2.343856  1.041842  0.219060  1.947285  2.320965
# 565  1.704854  2.085134  1.723842  0.102458 -0.017833  0.693043  1.263669
# 566  0.702284  2.045574  0.577953 -0.840484 -0.038680  0.046588  0.105777
# 567  1.838341  2.336457  1.735218  1.525767  3.272144  3.296944  2.658866
# 568 -1.808401  1.221792 -1.347789 -3.112085 -1.150752 -1.114873 -1.261820
#
#      exame_10  exame_11  exame_12  ...  exame_21  exame_22  exame_23  \
# ...

# %%
classificar(valores_exames_v5)
# Out:
# Resultados da Classificação 92.98%

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

kmelhores = SelectKBest(chi2, k = 5)

# %%
  treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v5, diagnostico, test_size = 0.3)

  kmelhores.fit(treino_x, treino_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-58529648bd33> in <module>()
#       1 treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v5, diagnostico, test_size = 0.3)
#       2
# ----> 3 kmelhores.fit(treino_x, treino_y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py in fit(self, X, y)
#     406
#     407         self._check_params(X, y)
# --> 408         score_func_ret = self.score_func(X, y)
#     409         if isinstance(score_func_ret, (list, tuple)):
#     410             self.scores_, self.pvalues_ = score_func_ret
#
# /usr/local/lib/python3.7/dist-packages/sklearn/feature_selection/_univariate_selection.py in chi2(X, y)
#     213     X = check_array(X, accept_sparse="csr")
#     214     if np.any((X.data if issparse(X) else X) < 0):
# ...

# %%
valores_exames_v6 = valores_exames_v1.drop(columns = (['exame_3','exame_4', 'exame_24', 'exame_29']))

# %%
valores_exames_v6.head()
# Out:
#    exame_1  exame_2  exame_5  exame_6  exame_7  exame_8  exame_9  exame_10  \
# 0    17.99    10.38   1001.0  0.11840  0.27760   0.3001  0.14710    0.2419
# 1    20.57    17.77   1326.0  0.08474  0.07864   0.0869  0.07017    0.1812
# 2    19.69    21.25   1203.0  0.10960  0.15990   0.1974  0.12790    0.2069
# 3    11.42    20.38    386.1  0.14250  0.28390   0.2414  0.10520    0.2597
# 4    20.29    14.34   1297.0  0.10030  0.13280   0.1980  0.10430    0.1809
#
#    exame_11  exame_12  ...  exame_21  exame_22  exame_23  exame_25  exame_26  \
# 0   0.07871    1.0950  ...  0.006193     25.38     17.33    2019.0    0.1622
# 1   0.05667    0.5435  ...  0.003532     24.99     23.41    1956.0    0.1238
# 2   0.05999    0.7456  ...  0.004571     23.57     25.53    1709.0    0.1444
# 3   0.09744    0.4956  ...  0.009208     14.91     26.50     567.7    0.2098
# 4   0.05883    0.7572  ...  0.005115     22.54     16.67    1575.0    0.1374
#
#    exame_27  exame_28  exame_30  exame_31  exame_32
# ...

# %%
SEED = 1234
random.seed(SEED)

treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v6, diagnostico, test_size = 0.3)

kmelhores.fit(treino_x, treino_y)

treino_kbest = kmelhores.transform(treino_x)
teste_kbest = kmelhores.transform(teste_x)

# %%
treino_kbest.shape
# Out:
# (398, 5)

# %%
teste_kbest.shape
# Out:
# (171, 5)

# %%
classificador = RandomForestClassifier(n_estimators = 100, random_state = 1234)
classificador.fit(treino_kbest, treino_y)

print("Resultados da Classificação %.2f%%" %(classificador.score(teste_kbest, teste_y)*100))
# Out:
# Resultados da Classificação 92.40%

# %%
from sklearn.metrics import confusion_matrix

matriz_confusao = confusion_matrix(teste_y, classificador.predict(teste_kbest))

# %%
matriz_confusao
# Out:
# array([[100,   5],
#        [  8,  58]])

# %%
sns.set(font_scale = 1.5)
sns.heatmap(matriz_confusao, annot = True, fmt = 'd').set(xlabel = 'Predição', ylabel = 'Real')
# Out:
# [Text(22.5, 0.5, 'Real'), Text(0.5, 4.5, 'Predição')]

# %%
from sklearn.feature_selection import RFE

SEED = 1234
random.seed(SEED)

treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v6, diagnostico, test_size = 0.3)

classificador = RandomForestClassifier(n_estimators = 100, random_state = 1234)
classificador.fit(treino_x, treino_y)

selecionar_rfe = RFE(estimator = classificador, n_features_to_select = 5,step = 1)
selecionar_rfe.fit(treino_x, treino_y)

treino_rfe = selecionar_rfe.transform(treino_x)
teste_rfe = selecionar_rfe.transform(teste_x)

classificador.fit(treino_rfe, treino_y)

matriz_confusao = confusion_matrix(teste_y, classificador.predict(teste_rfe))

sns.set(font_scale = 1.5)
sns.heatmap(matriz_confusao, annot = True, fmt = 'd').set(xlabel = 'Predição', ylabel = 'Real')

print("Resultados da Classificação %.2f%%" %(classificador.score(teste_rfe, teste_y)*100))
# Out:
# Resultados da Classificação 90.06%

# %%
from sklearn.feature_selection import RFECV

SEED = 1234
random.seed(SEED)

treino_x, teste_x, treino_y, teste_y = train_test_split(valores_exames_v6, diagnostico, test_size = 0.3)

classificador = RandomForestClassifier(n_estimators = 100, random_state = 1234)
classificador.fit(treino_x, treino_y)

selecionar_rfecv = RFECV(estimator = classificador, cv = 5 ,step = 1, scoring = 'accuracy')
selecionar_rfecv.fit(treino_x, treino_y)

treino_rfecv = selecionar_rfecv.transform(treino_x)
teste_rfecv = selecionar_rfecv.transform(teste_x)

classificador.fit(treino_rfecv, treino_y)

matriz_confusao = confusion_matrix(teste_y, classificador.predict(teste_rfecv))

sns.set(font_scale = 1.5)
sns.heatmap(matriz_confusao, annot = True, fmt = 'd').set(xlabel = 'Predição', ylabel = 'Real')

print("Resultados da Classificação %.2f%%" %(classificador.score(teste_rfecv, teste_y)*100))
# Out:
# Resultados da Classificação 92.98%

# %%
selecionar_rfecv.n_features_
# Out:
# 26

# %%
treino_x.columns[selecionar_rfecv.support_]
# Out:
# Index(['exame_1', 'exame_2', 'exame_5', 'exame_6', 'exame_7', 'exame_8',
#        'exame_9', 'exame_10', 'exame_12', 'exame_13', 'exame_14', 'exame_15',
#        'exame_16', 'exame_18', 'exame_19', 'exame_20', 'exame_21', 'exame_22',
#        'exame_23', 'exame_25', 'exame_26', 'exame_27', 'exame_28', 'exame_30',
#        'exame_31', 'exame_32'],
#       dtype='object')

# %%
valores_exames_v6.shape
# Out:
# (569, 28)

# %%
selecionar_rfecv.grid_scores_
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:103: FutureWarning: The `grid_scores_` attribute is deprecated in version 1.0 in favor of `cv_results_` and will be removed in version 1.2.
#   warnings.warn(msg, category=FutureWarning)
# array([[0.85      , 0.8875    , 0.8625    , 0.89873418, 0.84810127],
#        [0.9375    , 0.9375    , 0.9625    , 0.93670886, 0.88607595],
#        [0.925     , 0.95      , 0.95      , 0.97468354, 0.93670886],
#        [0.9125    , 0.95      , 0.9625    , 0.96202532, 0.93670886],
#        [0.9375    , 0.9375    , 0.9625    , 0.98734177, 0.93670886],
#        [0.9375    , 0.95      , 0.9625    , 0.96202532, 0.93670886],
#        [0.9375    , 0.95      , 0.9625    , 0.97468354, 0.93670886],
#        [0.925     , 0.975     , 0.975     , 0.98734177, 0.94936709],
#        [0.9125    , 0.9625    , 0.95      , 0.97468354, 0.93670886],
#        [0.925     , 0.9625    , 0.975     , 0.96202532, 0.93670886],
# ...

# %%
plt.figure(figsize = (14,8))

plt.xlabel('Número de Exames')
plt.ylabel('Acurácia')

plt.plot(range(1, len(selecionar_rfecv.grid_scores_) +1), selecionar_rfecv.grid_scores_)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:103: FutureWarning: The `grid_scores_` attribute is deprecated in version 1.0 in favor of `cv_results_` and will be removed in version 1.2.
#   warnings.warn(msg, category=FutureWarning)

# %%
resultados_exames
# Out:
#            id diagnostico  exame_1  exame_2  exame_3  exame_4  exame_5  \
# 0      842302           M    17.99    10.38   122.80   103.78   1001.0
# 1      842517           M    20.57    17.77   132.90   103.78   1326.0
# 2    84300903           M    19.69    21.25   130.00   103.78   1203.0
# 3    84348301           M    11.42    20.38    77.58   103.78    386.1
# 4    84358402           M    20.29    14.34   135.10   103.78   1297.0
# ..        ...         ...      ...      ...      ...      ...      ...
# 564    926424           M    21.56    22.39   142.00   103.78   1479.0
# 565    926682           M    20.13    28.25   131.20   103.78   1261.0
# 566    926954           M    16.60    28.08   108.30   103.78    858.1
# 567    927241           M    20.60    29.33   140.10   103.78   1265.0
# 568     92751           B     7.76    24.54    47.92   103.78    181.0
#
#      exame_6  exame_7  exame_8  ...  exame_24  exame_25  exame_26  exame_27  \
# ...

# %%
selecionar_rfe = RFE(estimator = classificador, n_features_to_select = 2,step = 1)
selecionar_rfe.fit(treino_x, treino_y)
# Out:
# RFE(estimator=RandomForestClassifier(random_state=1234), n_features_to_select=2)

# %%
valores_exames_v7 = selecionar_rfe.transform(valores_exames_v6)

# %%
valores_exames_v7.shape
# Out:
# (569, 2)

# %%
plt.figure(figsize = (14,8))
sns.scatterplot(x = valores_exames_v7[:,0], y = valores_exames_v7[:,1], hue = diagnostico,)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
valores_exames_v8 = pca.fit_transform(valores_exames_v5)

plt.figure(figsize = (14,8))
sns.scatterplot(x = valores_exames_v8[:,0], y = valores_exames_v8[:,1], hue = diagnostico,)

# %%
valores_exames_v8
# Out:
# array([[1157.37688421, -293.81017696],
#        [1267.4687997 ,   15.91568628],
#        [ 994.05000153,   39.07405468],
#        ...,
#        [ 313.54257115,   47.32093974],
#        [1121.40671014,   33.68512999],
#        [-769.01504719,  -87.76799118]])

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components = 2)
valores_exames_v9 = tsne.fit_transform(valores_exames_v5)

plt.figure(figsize = (14,8))
sns.scatterplot(x = valores_exames_v9[:,0], y = valores_exames_v9[:,1], hue = diagnostico,)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:783: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/manifold/_t_sne.py:793: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   FutureWarning,
